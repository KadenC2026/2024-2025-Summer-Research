# %% [markdown]
# <a href="https://colab.research.google.com/github/KadenC2026/Enviornment-Setup/blob/main/first_notebook_v01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Environment setup
#
# ## Abstract
#
# Our course will be developed throughout the theory of computational finance with relevant coding experiments. The classical setup for this computing is to install anaconda with python 3.X and GitHub desktop on your computer. To ease of our installation, we will use cloud computing platform with GitHub. In this part, we will learn the followings:
#
# - Setup GitHub account and a class repo.
# - Create a Jupyter notebook with Colab and update GitHub
#
# ## First touch with GitHub
# GitHub is exactly how people build software. GitHub. is a web-based hosting service for version control using Git. As of 2018, GitHub becomes the largest host of source code in the world, and Microsoft completed GitHub acquisition by the end of 2018. To learn GitHub, you may start with GitHub help.
#
# Let's start with the following steps:
#
# - Visit GitHub and register for your own account.
#
# - Create a repo with course-name. please tick public/initialize readme/mit license.
#
# - Modify README.md.

# %% [markdown]
# ## Jupyter notebook with Colab
# The Jupyter Notebook App is a server-client application that allows editing and running notebook documents (ex. python, latex) via a web browser. The Jupyter Notebook App can be executed on a local desktop requiring no internet access or can be installed on a remote server and accessed through the internet.

# %% [markdown]
# For instance, we can write math symbols using latex enclosed by double dollar sign:
# $$\phi(x)=\frac{1}{\sqrt{2\pi}} e^{-1/x^2}$$

# %%
'''===========
This is python code
=============='''
print('--->>> hello world! Here is the sin graph <<<-----')

import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-3, 3, 100)
plt.plot(x, np.sin(x));
# Out:
# --->>> hello world! Here is the sin graph <<<-----

# %% [markdown]
# Next, we use colab to add one jupyter notebook to your GitHub.
#
# - Google search 'colab', and create new python3 notebook
#
# - Change the file name as 'first_notebook_v01.ipynb'
#
# - Then you are going to write your first ipynb. you shall include at least one text cell and one code cell. In the text cell, you may test latex symbols too.
#
# - After finishing your edit of ipynb, you shall add it into your repo, by choosing 'saving a copy to GitHub' from the menu of colab. Check your GitHub repo again and save to 'src' subfolder.

# %% [markdown]
# ## Updating Readme
#
# README.md is initiated automatically as the frontpage of your github. Now, you want to update  it by giving a hyperlink to the above notebook. See
# [Markdown Cheatsheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet) for details of md file editing.

# %% [markdown]
# ## A workaround on GitHub error
#
# Sometimes, when viewing an *.ipynb on a GitHub blob page, it fails to load the page and give a  message "Sorry, something went wrong. Reload?" . I believe that is some temporary (and recurring) issue with their backend.
#
# A workround when it gives this message is that
# - Open "https://nbviewer.jupyter.org/"
# - Paste the link to your notebook.
